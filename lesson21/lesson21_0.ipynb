# %%
import os
import pandas as pd

file_names:list[str] = os.listdir('縣市長')
abs_paths:list[str] = []
for name in file_names:    
    if 'xls' in name:
        abs_paths.append(os.path.abspath(f'縣市長/{name}'))

pd.read_excel(abs_paths[0])
# Out:
#     107年雲林縣縣長選舉候選人在各投開票所得票數一覽表 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                         行政區別        村里別      投開票所別   各候選人得票情形
# 1                          NaN        NaN        NaN  1\n林佳瑜\n
# 2                          NaN        NaN        NaN        NaN
# 3                          NaN        NaN        NaN        NaN
# 4                         　麥寮鄉        NaN        NaN        340
# ..                         ...        ...        ...        ...
# 576                         　　        華南村        553          1
# 577                         　　        華山村        554          4
# 578                         　　        桂林村        555         14
# 579                         　　        樟湖村        556          1
# 580                         　　        草嶺村        557          3
#
#         Unnamed: 4 Unnamed: 5     Unnamed: 6             Unnamed: 7  \
# 0              NaN        NaN            NaN  A\n有效票數\n\nA=1+2+...N
# 1    2\n李進勇\n民主進步黨  3\n王麗萍\n   4\n張麗善\n中國國民黨                    NaN
# 2              NaN        NaN            NaN                    NaN
# 3              NaN        NaN            NaN                    NaN
# 4             6429        542          15550                  22861
# ..             ...        ...            ...                    ...
# 576            100          5             68                    174
# 577            181         10            284                    479
# 578            374         12            391                    791
# 579            163          4            197                    365
# 580            152          4            192                    351
#
#       Unnamed: 8       Unnamed: 9           Unnamed: 10       Unnamed: 11  \
# 0    B\n無效票數\n\n  C\n投票數\n\nC=A+B  D\n已領未投\n票　　數\nD=E-C  E\n發出票數\n\nE=C+D
# 1            NaN              NaN                   NaN               NaN
# 2            NaN              NaN                   NaN               NaN
# 3            NaN              NaN                   NaN               NaN
# 4           1338            24199                     4             24203
# ..           ...              ...                   ...               ...
# 576            7              181                     0               181
# 577           20              499                     0               499
# 578           29              820                     0               820
# 579           12              377                     0               377
# 580            3              354                     0               354
#
#      Unnamed: 12             Unnamed: 13         Unnamed: 14
# 0    F\n用餘票數\n\n  G\n選舉人數\n(原領票數)\nG=E+F  H\n投票率\nH=C/G\n(%)
# 1            NaN                     NaN                 NaN
# 2            NaN                     NaN                 NaN
# 3            NaN                     NaN                 NaN
# 4          11293                   35496           68.169998
# ..           ...                     ...                 ...
# 576          100                     281           64.410004
# 577          211                     710           70.279999
# 578          301                    1121           73.150002
# 579           68                     445           84.720001
# 580          209                     563           62.880001
#
# [581 rows x 15 columns]
