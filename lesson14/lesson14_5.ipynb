# %%
import pandas as pd
from pandas import DataFrame
aqi_df:DataFrame = pd.read_csv('新aqi.csv')
aqi_df
# Out:
#        站點名稱   城鎮  aqi        狀態                        日期
# 0    屏東(枋山)  屏東縣   54        普通  Sun 17 Mar 2024, 01:00PM
# 1    新北(樹林)  新北市   95        普通  Sun 17 Mar 2024, 01:00PM
# 2    屏東(琉球)  屏東縣   97        普通  Sun 17 Mar 2024, 01:00PM
# 3    臺南(麻豆)  臺南市   86        普通  Sun 17 Mar 2024, 01:00PM
# 4    高雄(湖內)  高雄市   64        普通  Sun 17 Mar 2024, 01:00PM
# ..      ...  ...  ...       ...                       ...
# 995      萬華  臺北市  100        普通  Sun 17 Mar 2024, 02:00AM
# 996      中山  臺北市   87        普通  Sun 17 Mar 2024, 02:00AM
# 997      士林  臺北市   84        普通  Sun 17 Mar 2024, 02:00AM
# 998      淡水  新北市   84        普通  Sun 17 Mar 2024, 02:00AM
# 999      林口  新北市  110  對敏感族群不健康  Sun 17 Mar 2024, 02:00AM
#
# [1000 rows x 5 columns]
